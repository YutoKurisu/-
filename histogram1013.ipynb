# %%
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import numpy as np
from pims.frame import Frame

# %%
with ND2Reader('collagencoat_C1control+_C2control-_C3collBL10_C4collBL25.nd2') as images:
    print (images.metadata)
# Out:
# {'height': 1022, 'width': 1024, 'date': None, 'fields_of_view': range(0, 100), 'frames': [0], 'z_levels': [], 'z_coordinates': [4226.5, 4226.76, 4226.92, 4227.06, 4227.22, 4227.38, 4227.22, 4227.06, 4226.9, 4226.74, 4227.0, 4227.2, 4227.36, 4227.5, 4227.66, 4227.84, 4227.66, 4227.54, 4227.4, 4227.26, 4227.5, 4227.66, 4227.82, 4227.92, 4228.06, 4227.54, 4227.54, 4227.36, 4227.24, 4227.1, 4227.16, 4227.32, 4227.46, 4227.64, 4227.86, 4227.96, 4227.9, 4227.72, 4227.58, 4227.38, 4227.56, 4227.66, 4227.8, 4227.96, 4228.1, 4228.14, 4228.1, 4227.9800000000005, 4227.8, 4227.66, 4223.36, 4223.5, 4223.52, 4223.4800000000005, 4223.46, 4223.28, 4223.26, 4223.28, 4223.34, 4223.38, 4223.24, 4223.24, 4223.24, 4223.22, 4223.22, 4223.02, 4223.02, 4223.04, 4223.1, 4223.14, 4222.9400000000005, 4222.92, 4222.92, 4222.92, 4222.92, 4225.68, 4225.86, 4225.78, 4225.68, 4225.54, 4225.3, 4225.38, 4225.56, 4225.68, 4226.04, 4225.68, 4225.56, 4225.4, 4225.32, 4225.22, 4224.96, 4225.02, 4225.1, 4225.18, 4225.36, 
# ...

# %%
dir(ND2Reader)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_clear_axes',
#  '_fh',
#  '_get',
#  '_get_default',
#  '_get_metadata_property',
#  '_guess_default_iter_axis',
#  '_init_axis',
#  '_init_axis_if_exists',
#  '_register_get_frame',
#  '_setup_axes',
#  '_slicerator_flag',
#  'axes',
#  'bundle_axes',
#  'class_exts',
#  'class_priority',
#  'close',
#  'default_coords',
#  'events',
#  'exts',
#  'frame_rate',
#  'frame_shape',
#  'get_frame',
#  'get_frame_2D',
#  'get_timesteps',
# ...

# %%
with ND2Reader('collagencoat_C1control+_C2control-_C3collBL10_C4collBL25.nd2') as images:
    print(images.sizes)
#     print(images[0])
    intensity_median = np.zeros(images.sizes["v"])
    # intensity_hist = None
    # intensity_hist_bins = np.zeros(images.sizes["v"])
    images.iter_axes = ['c', 'v']
    count = 0
    plt.figure(dpi=300)
    for i in range(images.sizes['v'] * images.sizes['c']):
#         print(image.metadata)
        if images[i].metadata['coords']['c'] == 2:
            intensities = images[i].ravel()
            if images[i].metadata['coords']['v'] in [26,31,43]:
                plt.hist(intensities, bins=400, alpha=0.3,range=(300,800))
            # plt.show()
            count += 1
    plt.show()
# Out:
# {'x': 1024, 'y': 1022, 'c': 3, 't': 1, 'v': 100}

# %%
intensity_hist[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/17/pblctml95wl2fwbr32s2hbkc0000gn/T/ipykernel_33970/3510177727.py in <module>
# ----> 1 intensity_hist[2]
#
# IndexError: tuple index out of range
